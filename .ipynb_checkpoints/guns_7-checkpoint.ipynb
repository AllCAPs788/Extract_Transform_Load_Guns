# %%
import pandas as pd
import glob
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
import pandas as pd
import glob
import os
path = os.path.join('Resources') # use your path
all_files = glob.glob(path + "/*.csv")
li = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)
frame = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# ### Transform premise DataFrame

# %%
frame
# Out:
#     Property Number        Date            Brand       Model Color   \
# 0            P18656  07/01/2016          BERETTA         NaN    BLK
# 1            P18684  07/02/2016   SMITH & WESSON   MP SHIELD    BLK
# 2            P18689  06/26/2016           MARLIN       RIFLE    GRY
# 3            P19120  07/18/2016            GLOCK         G30    BLK
# 4            P19121  07/18/2016           TAURUS      PT92SS    BLK
# ..              ...         ...              ...         ...    ...
# 195          P35364  03/01/2018  SMITH AND WESSO  M&P SHIELD    BLK
# 196          P35391  03/01/2018           TAURUS  PJ 24/7 G2    BLK
# 197          P35885  03/24/2018            COBRA        .380    BLK
# 198          P35940  03/26/2018              EAA      EA 9MM    PNK
# 199          P35949  03/26/2018              NaN         NaN    NaN
#
#      Stolen Locally Stolen From              Status Incident number Agency  \
# 0    Stolen Locally   Residence       Not Recovered       B16-25136    BPD
# 1    Stolen Locally     Vehicle       Not Recovered       B16-25258    BPD
# 2    Stolen Locally   Residence   Recovered Locally       B16-24702    BPD
# 3    Stolen Locally   Residence       Not Recovered       B16-27568    BPD
# 4    Stolen Locally   Residence       Not Recovered       B16-27568    BPD
# ..              ...         ...                 ...             ...    ...
# 195  Stolen Locally   RESIDENCE       Not Recovered       B18-08271    BPD
# 196  Stolen Locally   RESIDENCE       Not Recovered       B18-08309    BPD
# 197  Stolen Locally   RESIDENCE       Not Recovered       B18-11630    BPD
# 198  Stolen Locally   RESIDENCE       Not Recovered       B18-11938    BPD
# 199  Stolen Locally   RESIDENCE       Not Recovered       B18-11949    BPD
#
#     Stolen  Stolen Agency code
# 0       NaN    NaN         NaN
# 1       NaN    NaN         NaN
# 2       NaN    NaN         NaN
# 3       NaN    NaN         NaN
# 4       NaN    NaN         NaN
# ..      ...    ...         ...
# 195     NaN    NaN         NaN
# 196     NaN    NaN         NaN
# 197     NaN    NaN         NaN
# 198     NaN    NaN         NaN
# 199     NaN    NaN         NaN
#
# [200 rows x 13 columns]

# %% [markdown]
# ### Transform county DataFrame

# %% [markdown]
# ### Create database connection

# %% [markdown]
# ### Load DataFrames into database
